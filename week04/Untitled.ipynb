# %%
# for data wrangling
import pandas as pd

# for interactive plots
import plotly.express as px

# to import open data
from sodapy import Socrata

# %%
# connect to the data portal
client = Socrata("data.lacounty.gov", None)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("9trm-uz8i")

# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

# print it with .sample, which gives you random rows
df.sample(2)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#        situszip taxratearea_city         ain rollyear taxratearea  \
# 399  91304-3324      LOS ANGELES  2004002001     2021       00016
# 376  91304-3336      LOS ANGELES  2004001032     2014       00016
#
#        assessorid                        propertylocation usetype usecode  \
# 399  2004-002-001  22726 ECCLES ST  LOS ANGELES CA  91304     SFR    0101
# 376  2004-001-032   8309 PONCE AVE  LOS ANGELES CA  91304     SFR    0100
#
#     usecodedescchar1  ...       situscity situszip5           rowid  \
# 399      Residential  ...  LOS ANGELES CA     91304  20212004002001
# 376      Residential  ...  LOS ANGELES CA     91304  20142004001032
#
#              center_lat     center_lon  \
# 399  34.222627789999997  -118.62216293
# 376         34.21969133  -118.62185282
#
#                                             location_1  \
# 399  {'latitude': '34.22262779', 'longitude': '-118...
# ...

# %%
results = client.get("9trm-uz8i", 
                     limit = 25000, # putting an arbitrary high number (otherwise defaults to 1000)
                     where = "taxratearea_city ='Inglewood'"
                    )
