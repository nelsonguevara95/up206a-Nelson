# %% [markdown]
# # Census Data Exploration - Inglewood Income Profile
# By Nelson Guevara

# %% [markdown]
# ### Introduction
# In this assingment I will be creating an Income Profile for the City of Inglewood using 2019 Census Data. The project in itself is focused on the social and economic impacts that are facilitated with the development of major sports stadiums and arenas. To gain an understanding of the current state of Inglewood's housholds when it comes to income, I will be creating this profile to visualize the various levels of income and where those levels of income are in realtion to SoFi Stadium.

# %% [markdown]
# ### Step 1
# I will being by importing the libraries I will be using for this assingment. I will be importing geopandas, pandas, basemaps, and plots.

# %%
import pandas as pd

import geopandas as gpd

import contextily as ctx

import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2
# I now can import my census data.

# %%
income = gpd.read_file('Data/Income Data Inglewood 2019_Censustract.geojson')

# %% [markdown]
# ### Step 3
# I now will begin to inspect my data to get a better idea of what it looks like.

# %%
income.shape
# Out:
# (33, 37)

# %%
income.head()
# Out:
#                 geoid                                   name  B19001001  \
# 0  14000US06037600501  Census Tract 6005.01, Los Angeles, CA      871.0
# 1  14000US06037600502  Census Tract 6005.02, Los Angeles, CA      635.0
# 2  14000US06037600601  Census Tract 6006.01, Los Angeles, CA      920.0
# 3  14000US06037600602  Census Tract 6006.02, Los Angeles, CA      696.0
# 4  14000US06037600702  Census Tract 6007.02, Los Angeles, CA     1402.0
#
#    B19001001, Error  B19001002  B19001002, Error  B19001003  B19001003, Error  \
# 0              48.0       27.0              28.0       27.0              20.0
# 1              30.0       25.0              20.0       17.0              18.0
# 2              46.0       22.0              24.0       37.0              29.0
# 3              43.0       67.0              44.0       46.0              26.0
# 4              64.0       91.0              76.0       56.0              37.0
#
#    B19001004  B19001004, Error  ...  B19001013, Error  B19001014  \
# 0       43.0              31.0  ...              39.0      110.0
# 1        6.0               8.0  ...              18.0      105.0
# 2       32.0              26.0  ...              65.0       91.0
# 3       64.0              36.0  ...              33.0       36.0
# 4       10.0              14.0  ...              71.0      142.0
#
#    B19001014, Error  B19001015  B19001015, Error  B19001016  B19001016, Error  \
# 0              54.0       49.0              27.0       92.0              46.0
# 1              57.0       45.0              40.0       69.0              39.0
# 2              45.0       74.0              41.0      113.0              44.0
# 3              26.0       33.0              28.0       12.0              17.0
# 4              84.0      189.0              97.0      196.0              83.0
#
#    B19001017  B19001017, Error  \
# 0       59.0              33.0
# 1       31.0              26.0
# 2       28.0              20.0
# 3       13.0              16.0
# 4      170.0              84.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-118.32642 33.93293, -118.3264...
# 1  MULTIPOLYGON (((-118.33737 33.92796, -118.3373...
# 2  MULTIPOLYGON (((-118.32641 33.93870, -118.3264...
# 3  MULTIPOLYGON (((-118.33516 33.94108, -118.3351...
# 4  MULTIPOLYGON (((-118.34393 33.95271, -118.3439...
#
# [5 rows x 37 columns]

# %%
income.tail()
# Out:
#                  geoid                                   name  B19001001  \
# 28  14000US06037602003  Census Tract 6020.03, Los Angeles, CA     1258.0
# 29  14000US06037602004  Census Tract 6020.04, Los Angeles, CA     1052.0
# 30  14000US06037602104  Census Tract 6021.04, Los Angeles, CA     1739.0
# 31  14000US06037703002  Census Tract 7030.02, Los Angeles, CA     2859.0
# 32      16000US0636546                          Inglewood, CA    35997.0
#
#     B19001001, Error  B19001002  B19001002, Error  B19001003  \
# 28              59.0        0.0              12.0       92.0
# 29              40.0       18.0              20.0       54.0
# 30              50.0      126.0              79.0      136.0
# 31             150.0      200.0             142.0       66.0
# 32             780.0     2347.0             331.0     1872.0
#
#     B19001003, Error  B19001004  B19001004, Error  ...  B19001013, Error  \
# 28              61.0       57.0              40.0  ...              72.0
# 29              44.0       86.0              48.0  ...              62.0
# 30              79.0      106.0              67.0  ...              67.0
# 31              82.0       87.0              77.0  ...             127.0
# 32             287.0     1712.0             314.0  ...             444.0
#
#     B19001014  B19001014, Error  B19001015  B19001015, Error  B19001016  \
# 28       26.0              29.0       28.0              33.0       76.0
# 29       78.0              50.0       57.0              34.0        8.0
# 30      170.0              91.0        6.0              11.0       87.0
# 31      330.0             142.0      130.0              75.0      298.0
# 32     2905.0             365.0     1854.0             281.0     1796.0
#
#     B19001016, Error  B19001017  B19001017, Error  \
# 28              66.0       51.0              38.0
# 29              12.0       32.0              34.0
# 30              79.0       48.0              42.0
# 31             151.0      712.0             190.0
# 32             210.0     1410.0             259.0
#
#                                              geometry
# 28  MULTIPOLYGON (((-118.34390 33.93581, -118.3439...
# 29  MULTIPOLYGON (((-118.33514 33.93102, -118.3351...
# 30  MULTIPOLYGON (((-118.35247 33.93006, -118.3524...
# 31  MULTIPOLYGON (((-118.38655 33.97716, -118.3862...
# 32  MULTIPOLYGON (((-118.37625 33.98285, -118.3762...
#
# [5 rows x 37 columns]

# %%
income.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 4
# I want to view all of the columns in my data so I will change the options using the pandas module.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Now I will generate a sample to make sure all of my columns are displaying.

# %%
income.sample()
# Out:
#                 geoid                                   name  B19001001  \
# 2  14000US06037600601  Census Tract 6006.01, Los Angeles, CA      920.0
#
#    B19001001, Error  B19001002  B19001002, Error  B19001003  B19001003, Error  \
# 2              46.0       22.0              24.0       37.0              29.0
#
#    B19001004  B19001004, Error  B19001005  B19001005, Error  B19001006  \
# 2       32.0              26.0       16.0              13.0       37.0
#
#    B19001006, Error  B19001007  B19001007, Error  B19001008  B19001008, Error  \
# 2              23.0       30.0              22.0       60.0              35.0
#
#    B19001009  B19001009, Error  B19001010  B19001010, Error  B19001011  \
# 2       35.0              27.0       13.0              14.0       53.0
#
#    B19001011, Error  B19001012  B19001012, Error  B19001013  B19001013, Error  \
# 2              25.0       88.0              31.0      191.0              65.0
#
#    B19001014  B19001014, Error  B19001015  B19001015, Error  B19001016  \
# 2       91.0              45.0       74.0              41.0      113.0
#
#    B19001016, Error  B19001017  B19001017, Error  \
# 2              44.0       28.0              20.0
#
#                                             geometry
# 2  MULTIPOLYGON (((-118.32641 33.93870, -118.3264...

# %% [markdown]
# ### Step 5
# Now that I have all of the columns displaying, I want to get information about my data and look at the dtypes and non-null counts. I will do this by running the .info() command.

# %%
income.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             33 non-null     object
#  1   name              33 non-null     object
#  2   B19001001         33 non-null     float64
#  3   B19001001, Error  33 non-null     float64
#  4   B19001002         33 non-null     float64
#  5   B19001002, Error  33 non-null     float64
#  6   B19001003         33 non-null     float64
#  7   B19001003, Error  33 non-null     float64
#  8   B19001004         33 non-null     float64
#  9   B19001004, Error  33 non-null     float64
#  10  B19001005         33 non-null     float64
#  11  B19001005, Error  33 non-null     float64
#  12  B19001006         33 non-null     float64
#  13  B19001006, Error  33 non-null     float64
#  14  B19001007         33 non-null     float64
#  15  B19001007, Error  33 non-null     float64
#  16  B19001008         33 non-null     float64
#  17  B19001008, Error  33 non-null     float64
#  18  B19001009         33 non-null     float64
#  19  B19001009, Error  33 non-null     float64
#  20  B19001010         33 non-null     float64
#  21  B19001010, Error  33 non-null     float64
#  22  B19001011         33 non-null     float64
#  23  B19001011, Error  33 non-null     float64
#  24  B19001012         33 non-null     float64
#  25  B19001012, Error  33 non-null     float64
#  26  B19001013         33 non-null     float64
#  27  B19001013, Error  33 non-null     float64
#  28  B19001014         33 non-null     float64
#  29  B19001014, Error  33 non-null     float64
#  30  B19001015         33 non-null     float64
#  31  B19001015, Error  33 non-null     float64
#  32  B19001016         33 non-null     float64
#  33  B19001016, Error  33 non-null     float64
#  34  B19001017         33 non-null     float64
#  35  B19001017, Error  33 non-null     float64
#  36  geometry          33 non-null     geometry
# dtypes: float64(34), geometry(1), object(2)
# memory usage: 9.7+ KB

# %% [markdown]
# ### Step 6
# Now that I have a better sense about the data within the columns, I want to make sure that there is no 'summary' row that can potentially skew my data. I will check the top and bottom of the geoid column for a geoid that differs from the rest of them.

# %%
income.geoid.head()
# Out:
# 0    14000US06037600501
# 1    14000US06037600502
# 2    14000US06037600601
# 3    14000US06037600602
# 4    14000US06037600702
# Name: geoid, dtype: object

# %%
income.geoid.tail()
# Out:
# 28    14000US06037602003
# 29    14000US06037602004
# 30    14000US06037602104
# 31    14000US06037703002
# 32        16000US0636546
# Name: geoid, dtype: object

# %% [markdown]
# I see that in row 32 there is a different geoid so I will now drop that row of data since it is simply summarizing the rest of the rows in my data set.

# %%
income = income.drop([32])

# %% [markdown]
# Now I can double check my the top and bottom of my data to make sure that geoid is no longer in the data.

# %%
income.tail()
# Out:
#                  geoid                                   name  B19001001  \
# 27  14000US06037601900     Census Tract 6019, Los Angeles, CA     1238.0
# 28  14000US06037602003  Census Tract 6020.03, Los Angeles, CA     1258.0
# 29  14000US06037602004  Census Tract 6020.04, Los Angeles, CA     1052.0
# 30  14000US06037602104  Census Tract 6021.04, Los Angeles, CA     1739.0
# 31  14000US06037703002  Census Tract 7030.02, Los Angeles, CA     2859.0
#
#     B19001001, Error  B19001002  B19001002, Error  B19001003  \
# 27              66.0      138.0              78.0       30.0
# 28              59.0        0.0              12.0       92.0
# 29              40.0       18.0              20.0       54.0
# 30              50.0      126.0              79.0      136.0
# 31             150.0      200.0             142.0       66.0
#
#     B19001003, Error  B19001004  B19001004, Error  B19001005  \
# 27              32.0       72.0              59.0       13.0
# 28              61.0       57.0              40.0       35.0
# 29              44.0       86.0              48.0       81.0
# 30              79.0      106.0              67.0       85.0
# 31              82.0       87.0              77.0       99.0
#
#     B19001005, Error  B19001006  B19001006, Error  B19001007  \
# 27              16.0       26.0              43.0      125.0
# 28              35.0       64.0              50.0       56.0
# 29              56.0       44.0              39.0       48.0
# 30              71.0       70.0              53.0       32.0
# 31              78.0       96.0             108.0       18.0
#
#     B19001007, Error  B19001008  B19001008, Error  B19001009  \
# 27              74.0       44.0              37.0       43.0
# 28              46.0      122.0              67.0      192.0
# 29              38.0       64.0              41.0       32.0
# 30              33.0       80.0              68.0       42.0
# 31              28.0       53.0              46.0       79.0
#
#     B19001009, Error  B19001010  B19001010, Error  B19001011  \
# 27              46.0      103.0              67.0      101.0
# 28              90.0       39.0              30.0      119.0
# 29              31.0       57.0              46.0       91.0
# 30              47.0      154.0              90.0      174.0
# 31             101.0       69.0              51.0      113.0
#
#     B19001011, Error  B19001012  B19001012, Error  B19001013  \
# 27              69.0      159.0              86.0      210.0
# 28              65.0      143.0              70.0      158.0
# 29              44.0      147.0              60.0      155.0
# 30              70.0      213.0              91.0      210.0
# 31              81.0      195.0             109.0      314.0
#
#     B19001013, Error  B19001014  B19001014, Error  B19001015  \
# 27              84.0       97.0              72.0       36.0
# 28              72.0       26.0              29.0       28.0
# 29              62.0       78.0              50.0       57.0
# 30              67.0      170.0              91.0        6.0
# 31             127.0      330.0             142.0      130.0
#
#     B19001015, Error  B19001016  B19001016, Error  B19001017  \
# 27              35.0       14.0              22.0       27.0
# 28              33.0       76.0              66.0       51.0
# 29              34.0        8.0              12.0       32.0
# 30              11.0       87.0              79.0       48.0
# 31              75.0      298.0             151.0      712.0
#
#     B19001017, Error                                           geometry
# 27              37.0  MULTIPOLYGON (((-118.34391 33.94545, -118.3434...
# 28              38.0  MULTIPOLYGON (((-118.34390 33.93581, -118.3439...
# 29              34.0  MULTIPOLYGON (((-118.33514 33.93102, -118.3351...
# 30              42.0  MULTIPOLYGON (((-118.35247 33.93006, -118.3524...
# 31             190.0  MULTIPOLYGON (((-118.38655 33.97716, -118.3862...

# %% [markdown]
# ### Step 7 - Sorting and Renaming columns
# I want to begin sorting my columns and renaming them so that I can see what data I am looking at for each column. First, I will sort my columns to display the non-error columns. I begin by generating a list of the current columns:

# %%
list(income)
# Out:
# ['geoid',
#  'name',
#  'B19001001',
#  'B19001001, Error',
#  'B19001002',
#  'B19001002, Error',
#  'B19001003',
#  'B19001003, Error',
#  'B19001004',
#  'B19001004, Error',
#  'B19001005',
#  'B19001005, Error',
#  'B19001006',
#  'B19001006, Error',
#  'B19001007',
#  'B19001007, Error',
#  'B19001008',
#  'B19001008, Error',
#  'B19001009',
#  'B19001009, Error',
#  'B19001010',
#  'B19001010, Error',
#  'B19001011',
#  'B19001011, Error',
#  'B19001012',
#  'B19001012, Error',
#  'B19001013',
#  'B19001013, Error',
#  'B19001014',
#  'B19001014, Error',
#  'B19001015',
#  'B19001015, Error',
#  'B19001016',
#  'B19001016, Error',
#  'B19001017',
#  'B19001017, Error',
#  'geometry']

# %% [markdown]
# Now I can sort them, and I sort by excluding the columns that had 'error' in them.

# %%
columns_sorted = ['geoid',
 'name',
 'B19001001',
 'B19001002',
 'B19001003',
 'B19001004',
 'B19001005',
 'B19001006',
 'B19001007',
 'B19001008',
 'B19001009',
 'B19001010',
 'B19001011',                 
 'B19001012',
 'B19001013',
 'B19001014',
 'B19001015',
 'B19001016',
 'B19001017',
 'geometry']

# %% [markdown]
# I can now generate my 'income' variable to include only the sorted columns.

# %%
income = income[columns_sorted]

# %%
income.head()
# Out:
#                 geoid                                   name  B19001001  \
# 0  14000US06037600501  Census Tract 6005.01, Los Angeles, CA      871.0
# 1  14000US06037600502  Census Tract 6005.02, Los Angeles, CA      635.0
# 2  14000US06037600601  Census Tract 6006.01, Los Angeles, CA      920.0
# 3  14000US06037600602  Census Tract 6006.02, Los Angeles, CA      696.0
# 4  14000US06037600702  Census Tract 6007.02, Los Angeles, CA     1402.0
#
#    B19001002  B19001003  B19001004  B19001005  B19001006  B19001007  \
# 0       27.0       27.0       43.0       45.0       11.0       50.0
# 1       25.0       17.0        6.0       38.0        8.0       32.0
# 2       22.0       37.0       32.0       16.0       37.0       30.0
# 3       67.0       46.0       64.0       34.0       19.0       64.0
# 4       91.0       56.0       10.0       36.0       10.0       76.0
#
#    B19001008  B19001009  B19001010  B19001011  B19001012  B19001013  \
# 0       22.0       33.0       35.0       63.0      112.0       93.0
# 1       32.0        5.0       46.0       38.0      114.0       24.0
# 2       60.0       35.0       13.0       53.0       88.0      191.0
# 3       42.0       35.0       33.0       72.0       70.0       56.0
# 4       28.0       23.0       33.0       79.0      113.0      150.0
#
#    B19001014  B19001015  B19001016  B19001017  \
# 0      110.0       49.0       92.0       59.0
# 1      105.0       45.0       69.0       31.0
# 2       91.0       74.0      113.0       28.0
# 3       36.0       33.0       12.0       13.0
# 4      142.0      189.0      196.0      170.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-118.32642 33.93293, -118.3264...
# 1  MULTIPOLYGON (((-118.33737 33.92796, -118.3373...
# 2  MULTIPOLYGON (((-118.32641 33.93870, -118.3264...
# 3  MULTIPOLYGON (((-118.33516 33.94108, -118.3351...
# 4  MULTIPOLYGON (((-118.34393 33.95271, -118.3439...

# %% [markdown]
# Now I can finally rename each column. I am able to do this by opening the metadata.json file and cross referencing the names associated with each column and paste them into the *income.columns* command.

# %%
income.columns = ['geoid',
 'name',
 'Total',
 'Less than $10,000',
 '$10,000 to 14,999',
 '$15,000 to 19,999',
 '$20,000 to 24,999',
 '$25,000 to 29,999',
 '$30,000 to 34,999',
 '$35,000 to 39,999',
 '$40,000 to 44,999',
 '$45,000 to 49,999',                
 '$50,000 to 59,999',
 '$60,000 to 74,999',
 '$75,000 to 99,999',
 '$100,000 to 124,999',
 '$125,000 to 149,999', 
 '$150,000 to 199,999',
 '$200,000 or more',
 'geometry']

# %%
income['under $30,0000'] = income['Less than $10,000'] + income['$10,000 to 14,999'] + income['$15,000 to 19,999'] + income['$20,000 to 24,999'] + income['$25,000 to 29,999']
income['$30,000 - $59,999'] = income['$30,000 to 34,999'] + income['$35,000 to 39,999'] + income['$40,000 to 44,999'] + income['$45,000 to 49,999'] + income['$50,000 to 59,999']
income['$60,000 - $99,999'] = income['$60,000 to 74,999'] + income['$75,000 to 99,999']
income['$100,000 - $149,999'] = income['$100,000 to 124,999'] + income['$125,000 to 149,999']
income['$150,000 and above'] = income['$150,000 to 199,999'] + income['$200,000 or more']

# %% [markdown]
# I double check that my columns have been renamed by running the *.head* command.

# %%
income.head()
# Out:
#                 geoid                                   name   Total  \
# 0  14000US06037600501  Census Tract 6005.01, Los Angeles, CA   871.0
# 1  14000US06037600502  Census Tract 6005.02, Los Angeles, CA   635.0
# 2  14000US06037600601  Census Tract 6006.01, Los Angeles, CA   920.0
# 3  14000US06037600602  Census Tract 6006.02, Los Angeles, CA   696.0
# 4  14000US06037600702  Census Tract 6007.02, Los Angeles, CA  1402.0
#
#    Less than $10,000  $10,000 to 14,999  $15,000 to 19,999  $20,000 to 24,999  \
# 0               27.0               27.0               43.0               45.0
# 1               25.0               17.0                6.0               38.0
# 2               22.0               37.0               32.0               16.0
# 3               67.0               46.0               64.0               34.0
# 4               91.0               56.0               10.0               36.0
#
#    $25,000 to 29,999  $30,000 to 34,999  $35,000 to 39,999  $40,000 to 44,999  \
# 0               11.0               50.0               22.0               33.0
# 1                8.0               32.0               32.0                5.0
# 2               37.0               30.0               60.0               35.0
# 3               19.0               64.0               42.0               35.0
# 4               10.0               76.0               28.0               23.0
#
#    $45,000 to 49,999  $50,000 to 59,999  $60,000 to 74,999  $75,000 to 99,999  \
# 0               35.0               63.0              112.0               93.0
# 1               46.0               38.0              114.0               24.0
# 2               13.0               53.0               88.0              191.0
# 3               33.0               72.0               70.0               56.0
# 4               33.0               79.0              113.0              150.0
#
#    $100,000 to 124,999  $125,000 to 149,999  $150,000 to 199,999  \
# 0                110.0                 49.0                 92.0
# 1                105.0                 45.0                 69.0
# 2                 91.0                 74.0                113.0
# 3                 36.0                 33.0                 12.0
# 4                142.0                189.0                196.0
#
#    $200,000 or more                                           geometry  \
# 0              59.0  MULTIPOLYGON (((-118.32642 33.93293, -118.3264...
# 1              31.0  MULTIPOLYGON (((-118.33737 33.92796, -118.3373...
# 2              28.0  MULTIPOLYGON (((-118.32641 33.93870, -118.3264...
# 3              13.0  MULTIPOLYGON (((-118.33516 33.94108, -118.3351...
# 4             170.0  MULTIPOLYGON (((-118.34393 33.95271, -118.3439...
#
#    under $30,0000  $30,000 - $59,999  $60,000 - $99,999  $100,000 - $149,999  \
# 0           153.0              203.0              205.0                159.0
# 1            94.0              153.0              138.0                150.0
# 2           144.0              191.0              279.0                165.0
# 3           230.0              246.0              126.0                 69.0
# 4           203.0              239.0              263.0                331.0
#
#    $150,000 and above
# 0               151.0
# 1               100.0
# 2               141.0
# 3                25.0
# 4               366.0

# %%
new_columns_to_keep = ['geoid',        # These are the columns I am deciding to keep
    'name',
    'Total',
    'under $30,0000',                   
    '$30,000 - $59,999',
    '$60,000 - $99,999',
    '$100,000 - $149,999',
    '$150,000 and above',
    'geometry']

# %%
income = income[new_columns_to_keep]
income.sample()
# Out:
#                 geoid                                   name  Total  \
# 0  14000US06037600501  Census Tract 6005.01, Los Angeles, CA  871.0
#
#    under $30,0000  $30,000 - $59,999  $60,000 - $99,999  $100,000 - $149,999  \
# 0           153.0              203.0              205.0                159.0
#
#    $150,000 and above                                           geometry
# 0               151.0  MULTIPOLYGON (((-118.32642 33.93293, -118.3264...

# %% [markdown]
# ### Step 8 - Checking Data Integrity
# I want to make sure that my data has not been damaged in the process so far so I will run some basic data descriptive commands with a generted sample. I begin by generating one sample and creating a variable for that sample.

# %%
random_tract = income.sample()
random_tract
# Out:
#                  geoid                                   name   Total  \
# 13  14000US06037601002  Census Tract 6010.02, Los Angeles, CA  1894.0
#
#     under $30,0000  $30,000 - $59,999  $60,000 - $99,999  $100,000 - $149,999  \
# 13           441.0              682.0              553.0                145.0
#
#     $150,000 and above                                           geometry
# 13                73.0  MULTIPOLYGON (((-118.35259 33.95316, -118.3525...

# %% [markdown]
# Now that I have a variable for that sample generated , I will use the "Total" column to reference that my data adds up correctly. The sample census tract that I generated has a total of 1127 households:

# %%
random_tract.iloc[0]['Total']
# Out:
# 1894.0

# %% [markdown]
# I want to make sure I understand the previous code in plain english so I will use the print command to make it clear that the total number of households in this census tract is 1127.

# %%
print('Total Households: ' + str(random_tract.iloc[0]['Total']))
# Out:
# Total Households: 1894.0

# %% [markdown]
# Now I can check the integrity of my data by adding the rest of the columns together. I expect it to (and hope) add up to 1127 households.

# %%
print(random_tract.iloc[0]['under $30,0000'] + 
      random_tract.iloc[0]['$30,000 - $59,999'] + 
      random_tract.iloc[0]['$60,000 - $99,999'] + 
      random_tract.iloc[0]['$100,000 - $149,999'] + 
      random_tract.iloc[0]['$150,000 and above'])
# Out:
# 1894.0

# %% [markdown]
# ### Step 9 - Simple Data Statistics
# It does add up to 1127 and now I can begin doing more data descriptions for the "Total" column. I will first generate the average number of households in the entire city of Inglewood by using the *.mean* command.

# %%
income['Total'].mean()
# Out:
# 1376.09375

# %% [markdown]
# I now know what the average number of households is, but I also want to know what the median is. I can generate that information through the *.median* command.

# %%
income['Total'].median()
# Out:
# 1223.5

# %% [markdown]
# I can take a step further and genarete other information such as the standard deviation, the minimum, the max, and the percentiles for total number of households.

# %%
income['Total'].describe()
# Out:
# count      32.000000
# mean     1376.093750
# std       585.193233
# min       635.000000
# 25%       993.000000
# 50%      1223.500000
# 75%      1730.750000
# max      2859.000000
# Name: Total, dtype: float64

# %% [markdown]
# I want to create a histogram of the total number of households so I can have a visual representation of how frequent a number of total households is present in the data. After I run the *.plot.hist* command I can see that the most frequent total number of households is somewhere in the middle between 1000 and 1500.

# %%
income['Total'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Step 10 - Data Sorting and Initial Income Plots
# I want to begin mapping some of the data that I have, but first I want to sort the total number of households from highest to lowest so that I have a base of reference when looking at the income levels. Even though I have the percentages, I want to be able to map the ten most populated census tracts.
#
# I begin by sorting the values from highest to lowest with the following command:

# %%
income_sorted = income.sort_values(by='Total',ascending = False)

# %%
income_sorted[['geoid','Total']].head(10)
# Out:
#                  geoid   Total
# 31  14000US06037703002  2859.0
# 19  14000US06037601302  2795.0
# 9   14000US06037600902  2375.0
# 14  14000US06037601100  2104.0
# 20  14000US06037601303  2075.0
# 17  14000US06037601212  2068.0
# 13  14000US06037601002  1894.0
# 30  14000US06037602104  1739.0
# 21  14000US06037601401  1728.0
# 11  14000US06037600912  1447.0

# %% [markdown]
# Now that I have the census tracts with the most households, I want to plot them so I have a visual representation of where these tracts are located within Inglewood.

# %%
income_sorted.head(10).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Having total household information is great, but now I want to start looking at certain income levels. For the purpose of this assignemnt I will focus on the data for 20,000 to 24,999 dollars and 75,000 to 99,999 dollars.
#
# I begin by plotting the data for the number of households that earned between 20,000 and 24,999 dollars for all of the census tracts in Inglewood:

# %%
income_sorted.head(31).plot(figsize=(8,8),column='$30,000 - $59,999',legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# I will now do the same but for the households that earned between 75,000 and 99,999 dollars.

# %%
income_sorted.head(31).plot(figsize=(10,10),column='$60,000 - $99,999',legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 11 - Normalizing the Data
#
# These are great, but it is also limited. It simply plotted the raw number for each of those two categories without being able to determine what those numbers mean within these census tracts and all of Inglewood.
#
# I will try to normalize the data so that it can provide a bigger picture about what these numbers mean.
#
# I will do this by creating new columns with the percentage for each income bracket.

# %%
list(income)
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'under $30,0000',
#  '$30,000 - $59,999',
#  '$60,000 - $99,999',
#  '$100,000 - $149,999',
#  '$150,000 and above',
#  'geometry',
#  'Percent Less than $30,000',
#  'Percent $30,000 - $59,999',
#  'Percent $60,000 - $99,999',
#  'Percent $100,000 - $149,999',
#  'Percent $150,000 and above']

# %%
income['Percent Less than $30,000'] = income['under $30,0000']/income['Total']*100
income['Percent $30,000 - $59,999'] = income['$30,000 - $59,999']/income['Total']*100
income['Percent $60,000 - $99,999'] = income['$60,000 - $99,999']/income['Total']*100
income['Percent $100,000 - $149,999'] = income['$100,000 - $149,999']/income['Total']*100
income['Percent $150,000 and above'] = income['$150,000 and above']/income['Total']*100

# %% [markdown]
# In the cell above I created new percentage columns by taking the number of households that fall into each category and dividing them by the total followed by multiplying by 100. This gives me the percentage of households that fall into each category.
#
# I generate a sample to view my new columns.

# %%
income.sample(5)
# Out:
#                  geoid                                   name   Total  \
# 19  14000US06037601302  Census Tract 6013.02, Los Angeles, CA  2795.0
# 29  14000US06037602004  Census Tract 6020.04, Los Angeles, CA  1052.0
# 4   14000US06037600702  Census Tract 6007.02, Los Angeles, CA  1402.0
# 23  14000US06037601501  Census Tract 6015.01, Los Angeles, CA  1084.0
# 27  14000US06037601900     Census Tract 6019, Los Angeles, CA  1238.0
#
#     under $30,0000  $30,000 - $59,999  $60,000 - $99,999  $100,000 - $149,999  \
# 19           826.0              695.0              826.0                289.0
# 29           283.0              292.0              302.0                135.0
# 4            203.0              239.0              263.0                331.0
# 23           330.0              517.0              152.0                 67.0
# 27           279.0              416.0              369.0                133.0
#
#     $150,000 and above                                           geometry  \
# 19               159.0  MULTIPOLYGON (((-118.37282 33.96765, -118.3723...
# 29                40.0  MULTIPOLYGON (((-118.33514 33.93102, -118.3351...
# 4                366.0  MULTIPOLYGON (((-118.34393 33.95271, -118.3439...
# 23                18.0  MULTIPOLYGON (((-118.37004 33.94486, -118.3700...
# 27                41.0  MULTIPOLYGON (((-118.34391 33.94545, -118.3434...
#
#     Percent Less than $30,000  Percent $30,000 - $59,999  \
# 19                  29.552773                  24.865832
# 29                  26.901141                  27.756654
# 4                   14.479315                  17.047076
# 23                  30.442804                  47.693727
# 27                  22.536349                  33.602585
#
#     Percent $60,000 - $99,999  Percent $100,000 - $149,999  \
# 19                  29.552773                    10.339893
# 29                  28.707224                    12.832700
# 4                   18.758916                    23.609130
# 23                  14.022140                     6.180812
# 27                  29.806139                    10.743134
#
#     Percent $150,000 and above
# 19                    5.688730
# 29                    3.802281
# 4                    26.105563
# 23                    1.660517
# 27                    3.311793

# %% [markdown]
# Now I want to plot the percentages for the same data columns I used previously.
#
# I do this for 20,000 to 24,999 dollars and 75,000 to 99,999 dollars. I plot them in the equal interval scheme so that the different categories are evenly grouped.

# %%
income.plot(figsize=(12,10),
                 column='Percent $30,000 - $59,999',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot:>

# %%
income.plot(figsize=(12,10),
                 column='Percent $60,000 - $99,999',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 12 - Mapping
#
# I can now begin mapping some of the data that I have normalized.
#
# I begin by creating the same two plots I created in the previous step. I want them to be next to each other so that it is easier to view and compare.

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

ax1, ax2 = axs

income.plot(column='Percent $30,000 - $59,999', 
            cmap='RdYlGn_r', 
            scheme='quantiles',
            k=5, 
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, 
            legend=True
           )

ax1.axis("off")
ax1.set_title("Percent $30,000 to $59,999 Income Range")

income.plot(column='Percent $60,000 - $99,999', 
            cmap='RdYlGn_r', 
            scheme='quantiles',
            k=5, 
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, 
            legend=True
           )

ax2.axis("off")
ax2.set_title("Percent 60,000 to 99,999 Income Range")
# Out:
# Text(0.5, 1.0, 'Percent 60,000 to 99,999 Income Range')

# %% [markdown]
# These two plots next to each other now are able to provide a better visual of the differences for each of the two income categories I plotted. I can see that generally there is a higher concentration of households that ar withtin the 20,000 to 24,999 doallrs range in the southern part of Inglewood, and a higher concentration of households earning between 75,000 to 99,999 dollars in the northern part of Inglewood, for the most part.
#
# Now I want to see a certain percentage and above of the households that earn between 20,000 and 24,999. I will now generate a data frame that shows me the census tracts with more than 5% of households earning between 20,000 and 24,999 dollars.

# %%
income[income['Percent $60,000 - $99,999'] < 25]
# Out:
#                  geoid                                   name   Total  \
# 0   14000US06037600501  Census Tract 6005.01, Los Angeles, CA   871.0
# 1   14000US06037600502  Census Tract 6005.02, Los Angeles, CA   635.0
# 3   14000US06037600602  Census Tract 6006.02, Los Angeles, CA   696.0
# 4   14000US06037600702  Census Tract 6007.02, Los Angeles, CA  1402.0
# 5   14000US06037600703  Census Tract 6007.03, Los Angeles, CA   874.0
# 7   14000US06037600801  Census Tract 6008.01, Los Angeles, CA  1232.0
# 9   14000US06037600902  Census Tract 6009.02, Los Angeles, CA  2375.0
# 10  14000US06037600911  Census Tract 6009.11, Los Angeles, CA  1124.0
# 11  14000US06037600912  Census Tract 6009.12, Los Angeles, CA  1447.0
# 12  14000US06037601001  Census Tract 6010.01, Los Angeles, CA  1072.0
# 14  14000US06037601100     Census Tract 6011, Los Angeles, CA  2104.0
# 16  14000US06037601211  Census Tract 6012.11, Los Angeles, CA  1050.0
# 20  14000US06037601303  Census Tract 6013.03, Los Angeles, CA  2075.0
# 21  14000US06037601401  Census Tract 6014.01, Los Angeles, CA  1728.0
# 22  14000US06037601402  Census Tract 6014.02, Los Angeles, CA  1287.0
# 23  14000US06037601501  Census Tract 6015.01, Los Angeles, CA  1084.0
# 24  14000US06037601700     Census Tract 6017, Los Angeles, CA  1303.0
# 25  14000US06037601801  Census Tract 6018.01, Los Angeles, CA   802.0
# 28  14000US06037602003  Census Tract 6020.03, Los Angeles, CA  1258.0
# 30  14000US06037602104  Census Tract 6021.04, Los Angeles, CA  1739.0
# 31  14000US06037703002  Census Tract 7030.02, Los Angeles, CA  2859.0
#
#     under $30,0000  $30,000 - $59,999  $60,000 - $99,999  $100,000 - $149,999  \
# 0            153.0              203.0              205.0                159.0
# 1             94.0              153.0              138.0                150.0
# 3            230.0              246.0              126.0                 69.0
# 4            203.0              239.0              263.0                331.0
# 5            140.0              204.0              214.0                185.0
# 7            227.0              256.0              212.0                321.0
# 9            844.0              810.0              430.0                182.0
# 10           262.0              301.0              226.0                198.0
# 11           319.0              464.0              353.0                193.0
# 12           512.0              178.0              189.0                152.0
# 14           873.0              636.0              304.0                193.0
# 16           359.0              344.0              184.0                144.0
# 20           558.0              688.0              472.0                302.0
# 21           411.0              701.0              267.0                208.0
# 22           234.0              378.0              249.0                231.0
# 23           330.0              517.0              152.0                 67.0
# 24           443.0              362.0              322.0                150.0
# 25           310.0              183.0              193.0                 91.0
# 28           248.0              528.0              301.0                 54.0
# 30           523.0              482.0              423.0                176.0
# 31           548.0              332.0              509.0                460.0
#
#     $150,000 and above                                           geometry  \
# 0                151.0  MULTIPOLYGON (((-118.32642 33.93293, -118.3264...
# 1                100.0  MULTIPOLYGON (((-118.33737 33.92796, -118.3373...
# 3                 25.0  MULTIPOLYGON (((-118.33516 33.94108, -118.3351...
# 4                366.0  MULTIPOLYGON (((-118.34393 33.95271, -118.3439...
# 5                131.0  MULTIPOLYGON (((-118.34392 33.95796, -118.3439...
# 7                216.0  MULTIPOLYGON (((-118.32662 33.96180, -118.3265...
# 9                109.0  MULTIPOLYGON (((-118.35764 33.97457, -118.3576...
# 10               137.0  MULTIPOLYGON (((-118.35854 33.98167, -118.3579...
# 11               118.0  MULTIPOLYGON (((-118.34784 33.97174, -118.3472...
# 12                41.0  MULTIPOLYGON (((-118.35337 33.96539, -118.3533...
# 14                98.0  MULTIPOLYGON (((-118.35256 33.95271, -118.3525...
# 16                19.0  MULTIPOLYGON (((-118.36177 33.96619, -118.3617...
# 20                55.0  MULTIPOLYGON (((-118.36682 33.97702, -118.3662...
# 21               141.0  MULTIPOLYGON (((-118.37885 33.95437, -118.3788...
# 22               195.0  MULTIPOLYGON (((-118.37008 33.95631, -118.3700...
# 23                18.0  MULTIPOLYGON (((-118.37004 33.94486, -118.3700...
# 24                26.0  MULTIPOLYGON (((-118.35696 33.93393, -118.3569...
# 25                25.0  MULTIPOLYGON (((-118.35697 33.94260, -118.3569...
# 28               127.0  MULTIPOLYGON (((-118.34390 33.93581, -118.3439...
# 30               135.0  MULTIPOLYGON (((-118.35247 33.93006, -118.3524...
# 31              1010.0  MULTIPOLYGON (((-118.38655 33.97716, -118.3862...
#
#     Percent Less than $30,000  Percent $30,000 - $59,999  \
# 0                   17.566016                  23.306544
# 1                   14.803150                  24.094488
# 3                   33.045977                  35.344828
# 4                   14.479315                  17.047076
# 5                   16.018307                  23.340961
# 7                   18.425325                  20.779221
# 9                   35.536842                  34.105263
# 10                  23.309609                  26.779359
# 11                  22.045612                  32.066344
# 12                  47.761194                  16.604478
# 14                  41.492395                  30.228137
# 16                  34.190476                  32.761905
# 20                  26.891566                  33.156627
# 21                  23.784722                  40.567130
# 22                  18.181818                  29.370629
# 23                  30.442804                  47.693727
# 24                  33.998465                  27.782041
# 25                  38.653367                  22.817955
# 28                  19.713831                  41.971383
# 30                  30.074756                  27.717079
# 31                  19.167541                  11.612452
#
#     Percent $60,000 - $99,999  Percent $100,000 - $149,999  \
# 0                   23.536165                    18.254879
# 1                   21.732283                    23.622047
# 3                   18.103448                     9.913793
# 4                   18.758916                    23.609130
# 5                   24.485126                    21.167048
# 7                   17.207792                    26.055195
# 9                   18.105263                     7.663158
# 10                  20.106762                    17.615658
# 11                  24.395301                    13.337941
# 12                  17.630597                    14.179104
# 14                  14.448669                     9.173004
# 16                  17.523810                    13.714286
# 20                  22.746988                    14.554217
# 21                  15.451389                    12.037037
# 22                  19.347319                    17.948718
# 23                  14.022140                     6.180812
# 24                  24.712203                    11.511896
# 25                  24.064838                    11.346633
# 28                  23.926868                     4.292528
# 30                  24.324324                    10.120759
# 31                  17.803428                    16.089542
#
#     Percent $150,000 and above
# 0                    17.336395
# 1                    15.748031
# 3                     3.591954
# 4                    26.105563
# 5                    14.988558
# 7                    17.532468
# 9                     4.589474
# 10                   12.188612
# 11                    8.154803
# 12                    3.824627
# 14                    4.657795
# 16                    1.809524
# 20                    2.650602
# 21                    8.159722
# 22                   15.151515
# 23                    1.660517
# 24                    1.995395
# 25                    3.117207
# 28                   10.095390
# 30                    7.763082
# 31                   35.327037

# %% [markdown]
# There are a total of 14 census tracts in Inglewood that have over 5% of households earning between 20,000 and 24,999 dollars. I will now map this information with a basemap so that I can geographically locate these areas within Inglewood.
#
# I will add a basemap by using the contextily library.

# %%
income_web_mercator = income.to_crs(epsg=3857)

# %%
fig, ax = plt.subplots(figsize=(9, 9))

income_web_mercator[income_web_mercator['Percent $60,000 - $99,999'] < 25 ].plot(ax=ax, alpha=0.5)

ax.axis('off')

ax.set_title('Census Tracts with less than 25% of Households earning $60,000 to $99,999',fontsize=12)

ctx.add_basemap(ax)

# %% [markdown]
# # Results and Considerations
#
# This map shows me the areas within Inglewood in which over 5% of households earn between 20,000 and 24,999. Additionally the entire data when normalized is able to tell a more informative story about the different levlels of income in Inglewood. It also helps with comparing different census tracts. Something that it is hard to do with just the raw number of householdd that fall into each category.
#
# Some limitations in this exceercise is not being able to group certain categories together. I say this because in my basemap the 5% seems very low. This is becasue the data or percentages are being seperated into 16 or 17 different groups. In the future I could potentially create income brackets for low income, middle class income, high middle class, and high income by grouping some of the intervals from this data together. This would help create more meaningful visual represenations that make more sense when discussing social issues.
